# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt

# %%
plt.plot((1,2,3,4));

# %%
plt.plot([1,2,3,4],[1,4,9,16]);
plt.show()

# %%
plt.plot(np.arange(0,5));

# %%
l= np.arange(0,101)
l2= l **2
plt.plot(l,l2);

# %%
t= np.arange(0,2.5,0.1)
y1= np.sin(np.pi*t)
y2= np.sin(np.pi*t+np.pi/2)
y3= np.sin(np.pi*t-np.pi/2)
plt.subplot(311)
plt.plot(t,y1,'r--');
plt.subplot(312)
plt.plot(t,y2,'g^');
plt.subplot(313)
plt.plot(t,y3,'bs');

# %%
plt.plot(np.arange(1,10),linewidth= 5.0);

# %%
plt.axis([0,5,0,20])
plt.title('Plot')
plt.xlabel('counting')
plt.ylabel('Square values')
plt.text(1,1.5,'first');
plt.text(2,4.5,'second');
plt.text(3,9.5,'third')
plt.plot([1,2,3,4],[1,4,9,16],'ro');
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^');
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*');
plt.legend(['First series','Second series','Third series'],loc=1);
plt.grid();

# %%
pop = np.random.randint(0,100,100) 
plt.hist(pop,bins=20);

# %%
index = [0,1,2,3,4]
values = [5,7,3,4,6]
plt.bar(index,values);

# %%
labels = ['x','y','z']
values = [1,2,3]
plt.pie(values,labels=labels);

# %%
dx= 0.01;
dy=0.01

x = np.arange(-2.0,2.0,dx)
y=np.arange(-2.0,2.0,dy)
x,y=np.meshgrid(x,y)
def f(x,y):
  return (1-y**5+x**5)*np.exp(-x**2-y**2)

c = plt.contour(x,y,f(x,y),8,colors='black');
plt.contourf(x,y,f(x,y),8);
plt.clabel(c);

# %%
fig = plt.figure();
ax = Axes3D(fig);
x = np.arange(-2.0,2.0,dx)
y=np.arange(-2.0,2.0,dy)
x,y=np.meshgrid(x,y)
def f(x,y):
  return (1-y**5+x**5)*np.exp(-x**2-y**2)
ax.plot_surface(x,y,f(x,y),rstride=1,cstride=1);
# Out:
# <ipython-input-86-06791c4f27d9>:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
xs = np.random.randint(30,40,100)
ys = np.random.randint(20,30,100)
zs = np.random.randint(10,20,100)

fig = plt.figure();
ax = Axes3D(fig)
ax.scatter(xs,ys,zs);
# Out:
# <ipython-input-89-2d5c5a2a06c0>:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
